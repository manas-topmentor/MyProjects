# %%
a=int(input("Enter 1st Number : "))
b=int(input("Enter 2nd Number : "))
c=a+b
print("Addition :",c)
c=a-b
print("Substraction :",c)
c=a*b
print("Multiplication :",c)
c=a/b
print("Division :",c)
# Out:
# Enter 1st Number :  20
# Enter 2nd Number :  10
# Addition : 30
# Substraction : 10
# Multiplication : 200
# Division : 2.0
